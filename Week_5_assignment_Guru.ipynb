# %% [markdown]
# # DS Automation Assignment

# %% [markdown]
# Using our prepared churn data from week 2:
# - use pycaret to find an ML algorithm that performs best on the data
#     - Choose a metric you think is best to use for finding the best model; by default, it is accuracy but it could be AUC, precision, recall, etc. The week 3 FTE has some information on these different metrics.
# - save the model to disk
# - create a Python script/file/module with a function that takes a pandas dataframe as an input and returns the probability of churn for each row in the dataframe
#     - your Python file/function should print out the predictions for new data (new_churn_data.csv)
#     - the true values for the new data are [1, 0, 0, 1, 0] if you're interested
# - test your Python module and function with the new data, new_churn_data.csv
# - write a short summary of the process and results at the end of this notebook
# - upload this Jupyter Notebook and Python file to a Github repository, and turn in a link to the repository in the week 5 assignment dropbox
#
# *Optional* challenges:
# - return the probability of churn for each new prediction, and the percentile where that prediction is in the distribution of probability predictions from the training dataset (e.g. a high probability of churn like 0.78 might be at the 90th percentile)
# - use other autoML packages, such as TPOT, H2O, MLBox, etc, and compare performance and features with pycaret
# - create a class in your Python module to hold the functions that you created
# - accept user input to specify a file using a tool such as Python's `input()` function, the `click` package for command-line arguments, or a GUI
# - Use the unmodified churn data (new_unmodified_churn_data.csv) in your Python script. This will require adding the same preprocessing steps from week 2 since this data is like the original unmodified dataset from week 1.

# %%
pip install pycaret
# Out:
# Requirement already satisfied: pycaret in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (3.1.0)
# Requirement already satisfied: requests>=2.27.1 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (2.28.1)
# Requirement already satisfied: ipython>=5.5.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (8.7.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (5.7.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: schemdraw==0.15 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.15)
# Requirement already satisfied: xxhash in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (3.3.0)
# Requirement already satisfied: tbats>=1.1.3 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: scikit-learn<1.3.0,>=1.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.0.2)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.11.0)
# Requirement already satisfied: jinja2>=1.2 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (2.11.3)
# Requirement already satisfied: plotly>=5.0.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: scipy~=1.10.1 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.10.1)
# Requirement already satisfied: scikit-plot>=0.3.7 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (3.6.2)
# Requirement already satisfied: sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.21.1)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.9.1)
# Requirement already satisfied: lightgbm>=3.0.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (4.1.0)
# Requirement already satisfied: wurlitzer in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (3.0.2)
# Collecting numpy<1.24,>=1.21
#   Downloading numpy-1.23.5-cp39-cp39-macosx_10_9_x86_64.whl (18.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 26.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pyod>=1.0.8 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.1.0)
# Requirement already satisfied: deprecation>=2.1.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (7.6.5)
# Requirement already satisfied: kaleido>=0.2.1 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: statsmodels>=0.12.1 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.13.2)
# Requirement already satisfied: pandas<2.0.0,>=1.3.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.4.4)
# Requirement already satisfied: numba>=0.55.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.57.0)
# Requirement already satisfied: tqdm>=4.62.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (4.64.1)
# Requirement already satisfied: yellowbrick>=1.4 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.5)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (2.0.3)
# Requirement already satisfied: cloudpickle in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (6.8.0)
# Requirement already satisfied: category-encoders>=2.4.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (2.6.2)
# Requirement already satisfied: psutil>=5.9.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: markupsafe>=2.0.1 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (2.0.1)
# Requirement already satisfied: patsy>=0.5.1 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from category-encoders>=2.4.0->pycaret) (0.5.2)
# Requirement already satisfied: packaging in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from deprecation>=2.1.0->pycaret) (22.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from imbalanced-learn>=0.8.1->pycaret) (2.2.0)
# Requirement already satisfied: zipp>=0.5 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.12.0->pycaret) (3.11.0)
# Requirement already satisfied: decorator in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (2.11.2)
# Requirement already satisfied: traitlets>=5 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (5.7.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (3.0.36)
# Requirement already satisfied: jedi>=0.16 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: pexpect>4.3 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (4.8.0)
# Requirement already satisfied: appnope in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.1.2)
# Requirement already satisfied: stack-data in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: backcall in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: pickleshare in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.6.5->pycaret) (6.19.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.6.5->pycaret) (1.0.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.6.5->pycaret) (3.5.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (9.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (4.25.0)
# Requirement already satisfied: jupyter-core in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->pycaret) (5.1.1)
# Requirement already satisfied: fastjsonschema in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->pycaret) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->pycaret) (4.16.0)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from numba>=0.55.0->pycaret) (0.40.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pandas<2.0.0,>=1.3.0->pycaret) (2022.7)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from plotly>=5.0.0->pycaret) (8.0.1)
# Requirement already satisfied: trace-updater>=0.0.8 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.0.9.1)
# Requirement already satisfied: dash<3.0.0,>=2.11.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.13.0)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.9.7)
# Requirement already satisfied: tsdownsample==0.1.2 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.2)
# Requirement already satisfied: urllib3 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (1.26.14)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (65.6.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (0.29.32)
# Requirement already satisfied: six in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pyod>=1.0.8->pycaret) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.27.1->pycaret) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.27.1->pycaret) (2023.7.22)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Requirement already satisfied: scikit-base<0.6.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret) (0.5.1)
# Requirement already satisfied: deprecated>=1.2.13 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret) (1.2.14)
# Requirement already satisfied: retrying in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: nest-asyncio in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.5.6)
# Requirement already satisfied: ansi2html in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.8.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (4.4.0)
# Requirement already satisfied: Flask<2.3.0,>=1.0.4 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.1.2)
# Requirement already satisfied: dash-table==5.0.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: Werkzeug<2.3.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from deprecated>=1.2.13->sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret) (1.12.1)
# Requirement already satisfied: debugpy>=1.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.1)
# Requirement already satisfied: pyzmq>=17 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (23.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1.12)
# Requirement already satisfied: comm>=0.1.1 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: tornado>=6.1 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (22.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.5.0->pycaret) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.5.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (2.5.2)
# Requirement already satisfied: asttokens in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Requirement already satisfied: executing in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: click>=5.1 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from Flask<2.3.0,>=1.0.4->dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (8.0.4)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from Flask<2.3.0,>=1.0.4->dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.1)
# Requirement already satisfied: terminado>=0.8.3 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.17.1)
# Requirement already satisfied: prometheus-client in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.14.1)
# Requirement already satisfied: nbconvert>=5 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.4.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: argon2-cffi in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.3.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.4.8)
# Requirement already satisfied: notebook-shim>=0.1.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.23.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.13)
# Requirement already satisfied: jupyterlab-pygments in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.4)
# Requirement already satisfied: testpath in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.8.4)
# Requirement already satisfied: defusedxml in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.5.0)
# Requirement already satisfied: bleach in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.1.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.2.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (3.5.0)
# Requirement already satisfied: websocket-client in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.3.2.post1)
# Requirement already satisfied: webencodings in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.2.0)
# Requirement already satisfied: pycparser in /Users/gupthajavvaji/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.21)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.6.0 requires daal==2021.4.0, which is not installed.
# Successfully installed numpy-1.23.5
# Note: you may need to restart the kernel to use updated packages.

# %%
from pycaret.classification import *
import pandas as pd

# %%
# Load the data
data = pd.read_csv('cleaned_churn_data.csv')
data = data.drop(['tenure_charge_ratio', 'PhoneService_1', 'charge_to_tenure_ratio', 'customerID'], axis=1)
data
# Out:
#       tenure        Contract              PaymentMethod  MonthlyCharges  \
# 0          1  Month-to-month           Electronic check           29.85
# 1         34        One year               Mailed check           56.95
# 2          2  Month-to-month               Mailed check           53.85
# 3         45        One year  Bank transfer (automatic)           42.30
# 4          2  Month-to-month           Electronic check           70.70
# ...      ...             ...                        ...             ...
# 6949      24        One year               Mailed check           84.80
# 6950      72        One year    Credit card (automatic)          103.20
# 6951      11  Month-to-month           Electronic check           29.60
# 6952       4  Month-to-month               Mailed check           74.40
# 6953      66        Two year  Bank transfer (automatic)          105.65
#
#       TotalCharges Churn
# 0            29.85    No
# 1          1889.50    No
# 2           108.15   Yes
# 3          1840.75    No
# 4           151.65   Yes
# ...            ...   ...
# 6949       1990.50    No
# 6950       7362.90    No
# 6951        346.45    No
# 6952        306.60   Yes
# 6953       6844.50    No
#
# [6954 rows x 6 columns]

# %%
# Initializing the setup
clasification = setup(data, target='Churn')
# Out:
# <style type="text/css">
# #T_7c624_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7c624">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c624_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7c624_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c624_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c624_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_7c624_row0_col1" class="data row0 col1" >1379</td>
#     </tr>
#     <tr>
#       <th id="T_7c624_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7c624_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7c624_row1_col1" class="data row1 col1" >Churn</td>
#     </tr>
#     <tr>
#       <th id="T_7c624_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7c624_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_7c624_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_7c624_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7c624_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_7c624_row3_col1" class="data row3 col1" >No: 0, Yes: 1</td>
#     </tr>
#     <tr>
#       <th id="T_7c624_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7c624_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_7c624_row4_col1" class="data row4 col1" >(6954, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_7c624_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7c624_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_7c624_row5_col1" class="data row5 col1" >(6954, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_7c624_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7c624_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_7c624_row6_col1" class="data row6 col1" >(4867, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_7c624_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7c624_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_7c624_row7_col1" class="data row7 col1" >(2087, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_7c624_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7c624_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_7c624_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_7c624_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7c624_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_7c624_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_7c624_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7c624_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_7c624_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_7c624_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7c624_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_7c624_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_7c624_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7c624_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_7c624_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_7c624_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7c624_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_7c624_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_7c624_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7c624_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_7c624_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_7c624_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7c624_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_7c624_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7c624_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7c624_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_7c624_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_7c624_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7c624_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_7c624_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_7c624_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7c624_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_7c624_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_7c624_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_7c624_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_7c624_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7c624_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_7c624_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_7c624_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7c624_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_7c624_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_7c624_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_7c624_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_7c624_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_7c624_row22_col1" class="data row22 col1" >b79c</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Compare models and select the best one
best_model_data = compare_models()
# Out:
# <style type="text/css">
# #T_0fdf8 th {
#   text-align: left;
# }
# #T_0fdf8_row0_col0, #T_0fdf8_row0_col3, #T_0fdf8_row0_col5, #T_0fdf8_row0_col6, #T_0fdf8_row1_col0, #T_0fdf8_row1_col1, #T_0fdf8_row1_col2, #T_0fdf8_row1_col3, #T_0fdf8_row1_col4, #T_0fdf8_row1_col5, #T_0fdf8_row1_col6, #T_0fdf8_row1_col7, #T_0fdf8_row2_col0, #T_0fdf8_row2_col1, #T_0fdf8_row2_col2, #T_0fdf8_row2_col3, #T_0fdf8_row2_col4, #T_0fdf8_row2_col5, #T_0fdf8_row2_col6, #T_0fdf8_row2_col7, #T_0fdf8_row3_col0, #T_0fdf8_row3_col1, #T_0fdf8_row3_col2, #T_0fdf8_row3_col3, #T_0fdf8_row3_col4, #T_0fdf8_row3_col5, #T_0fdf8_row3_col7, #T_0fdf8_row4_col0, #T_0fdf8_row4_col1, #T_0fdf8_row4_col2, #T_0fdf8_row4_col3, #T_0fdf8_row4_col4, #T_0fdf8_row4_col5, #T_0fdf8_row4_col6, #T_0fdf8_row4_col7, #T_0fdf8_row5_col0, #T_0fdf8_row5_col1, #T_0fdf8_row5_col2, #T_0fdf8_row5_col3, #T_0fdf8_row5_col4, #T_0fdf8_row5_col5, #T_0fdf8_row5_col6, #T_0fdf8_row5_col7, #T_0fdf8_row6_col0, #T_0fdf8_row6_col1, #T_0fdf8_row6_col2, #T_0fdf8_row6_col3, #T_0fdf8_row6_col4, #T_0fdf8_row6_col5, #T_0fdf8_row6_col6, #T_0fdf8_row6_col7, #T_0fdf8_row7_col0, #T_0fdf8_row7_col1, #T_0fdf8_row7_col2, #T_0fdf8_row7_col3, #T_0fdf8_row7_col4, #T_0fdf8_row7_col5, #T_0fdf8_row7_col6, #T_0fdf8_row7_col7, #T_0fdf8_row8_col0, #T_0fdf8_row8_col1, #T_0fdf8_row8_col2, #T_0fdf8_row8_col3, #T_0fdf8_row8_col4, #T_0fdf8_row8_col5, #T_0fdf8_row8_col6, #T_0fdf8_row8_col7, #T_0fdf8_row9_col0, #T_0fdf8_row9_col1, #T_0fdf8_row9_col2, #T_0fdf8_row9_col3, #T_0fdf8_row9_col4, #T_0fdf8_row9_col5, #T_0fdf8_row9_col6, #T_0fdf8_row9_col7, #T_0fdf8_row10_col0, #T_0fdf8_row10_col1, #T_0fdf8_row10_col2, #T_0fdf8_row10_col3, #T_0fdf8_row10_col4, #T_0fdf8_row10_col5, #T_0fdf8_row10_col6, #T_0fdf8_row10_col7, #T_0fdf8_row11_col0, #T_0fdf8_row11_col1, #T_0fdf8_row11_col2, #T_0fdf8_row11_col3, #T_0fdf8_row11_col4, #T_0fdf8_row11_col5, #T_0fdf8_row11_col6, #T_0fdf8_row11_col7, #T_0fdf8_row12_col0, #T_0fdf8_row12_col1, #T_0fdf8_row12_col2, #T_0fdf8_row12_col4, #T_0fdf8_row12_col6, #T_0fdf8_row12_col7, #T_0fdf8_row13_col0, #T_0fdf8_row13_col1, #T_0fdf8_row13_col2, #T_0fdf8_row13_col3, #T_0fdf8_row13_col4, #T_0fdf8_row13_col5, #T_0fdf8_row13_col6, #T_0fdf8_row13_col7 {
#   text-align: left;
# }
# #T_0fdf8_row0_col1, #T_0fdf8_row0_col2, #T_0fdf8_row0_col4, #T_0fdf8_row0_col7, #T_0fdf8_row3_col6, #T_0fdf8_row12_col3, #T_0fdf8_row12_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_0fdf8_row0_col8, #T_0fdf8_row1_col8, #T_0fdf8_row2_col8, #T_0fdf8_row3_col8, #T_0fdf8_row5_col8, #T_0fdf8_row6_col8, #T_0fdf8_row7_col8, #T_0fdf8_row8_col8, #T_0fdf8_row9_col8, #T_0fdf8_row11_col8, #T_0fdf8_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_0fdf8_row4_col8, #T_0fdf8_row10_col8, #T_0fdf8_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_0fdf8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0fdf8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0fdf8_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_0fdf8_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_0fdf8_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_0fdf8_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_0fdf8_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_0fdf8_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_0fdf8_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_0fdf8_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0fdf8_level0_row0" class="row_heading level0 row0" >ada</th>
#       <td id="T_0fdf8_row0_col0" class="data row0 col0" >Ada Boost Classifier</td>
#       <td id="T_0fdf8_row0_col1" class="data row0 col1" >0.7931</td>
#       <td id="T_0fdf8_row0_col2" class="data row0 col2" >0.8434</td>
#       <td id="T_0fdf8_row0_col3" class="data row0 col3" >0.5092</td>
#       <td id="T_0fdf8_row0_col4" class="data row0 col4" >0.6475</td>
#       <td id="T_0fdf8_row0_col5" class="data row0 col5" >0.5690</td>
#       <td id="T_0fdf8_row0_col6" class="data row0 col6" >0.4356</td>
#       <td id="T_0fdf8_row0_col7" class="data row0 col7" >0.4417</td>
#       <td id="T_0fdf8_row0_col8" class="data row0 col8" >0.0470</td>
#     </tr>
#     <tr>
#       <th id="T_0fdf8_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_0fdf8_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_0fdf8_row1_col1" class="data row1 col1" >0.7919</td>
#       <td id="T_0fdf8_row1_col2" class="data row1 col2" >0.8418</td>
#       <td id="T_0fdf8_row1_col3" class="data row1 col3" >0.5099</td>
#       <td id="T_0fdf8_row1_col4" class="data row1 col4" >0.6427</td>
#       <td id="T_0fdf8_row1_col5" class="data row1 col5" >0.5675</td>
#       <td id="T_0fdf8_row1_col6" class="data row1 col6" >0.4331</td>
#       <td id="T_0fdf8_row1_col7" class="data row1 col7" >0.4388</td>
#       <td id="T_0fdf8_row1_col8" class="data row1 col8" >0.1010</td>
#     </tr>
#     <tr>
#       <th id="T_0fdf8_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_0fdf8_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_0fdf8_row2_col1" class="data row2 col1" >0.7890</td>
#       <td id="T_0fdf8_row2_col2" class="data row2 col2" >0.8337</td>
#       <td id="T_0fdf8_row2_col3" class="data row2 col3" >0.5176</td>
#       <td id="T_0fdf8_row2_col4" class="data row2 col4" >0.6321</td>
#       <td id="T_0fdf8_row2_col5" class="data row2 col5" >0.5685</td>
#       <td id="T_0fdf8_row2_col6" class="data row2 col6" >0.4307</td>
#       <td id="T_0fdf8_row2_col7" class="data row2 col7" >0.4349</td>
#       <td id="T_0fdf8_row2_col8" class="data row2 col8" >0.0330</td>
#     </tr>
#     <tr>
#       <th id="T_0fdf8_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_0fdf8_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_0fdf8_row3_col1" class="data row3 col1" >0.7888</td>
#       <td id="T_0fdf8_row3_col2" class="data row3 col2" >0.8334</td>
#       <td id="T_0fdf8_row3_col3" class="data row3 col3" >0.5382</td>
#       <td id="T_0fdf8_row3_col4" class="data row3 col4" >0.6249</td>
#       <td id="T_0fdf8_row3_col5" class="data row3 col5" >0.5776</td>
#       <td id="T_0fdf8_row3_col6" class="data row3 col6" >0.4379</td>
#       <td id="T_0fdf8_row3_col7" class="data row3 col7" >0.4406</td>
#       <td id="T_0fdf8_row3_col8" class="data row3 col8" >0.0320</td>
#     </tr>
#     <tr>
#       <th id="T_0fdf8_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_0fdf8_row4_col0" class="data row4 col0" >Ridge Classifier</td>
#       <td id="T_0fdf8_row4_col1" class="data row4 col1" >0.7871</td>
#       <td id="T_0fdf8_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_0fdf8_row4_col3" class="data row4 col3" >0.4701</td>
#       <td id="T_0fdf8_row4_col4" class="data row4 col4" >0.6416</td>
#       <td id="T_0fdf8_row4_col5" class="data row4 col5" >0.5416</td>
#       <td id="T_0fdf8_row4_col6" class="data row4 col6" >0.4075</td>
#       <td id="T_0fdf8_row4_col7" class="data row4 col7" >0.4164</td>
#       <td id="T_0fdf8_row4_col8" class="data row4 col8" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_0fdf8_level0_row5" class="row_heading level0 row5" >lda</th>
#       <td id="T_0fdf8_row5_col0" class="data row5 col0" >Linear Discriminant Analysis</td>
#       <td id="T_0fdf8_row5_col1" class="data row5 col1" >0.7863</td>
#       <td id="T_0fdf8_row5_col2" class="data row5 col2" >0.8253</td>
#       <td id="T_0fdf8_row5_col3" class="data row5 col3" >0.5299</td>
#       <td id="T_0fdf8_row5_col4" class="data row5 col4" >0.6199</td>
#       <td id="T_0fdf8_row5_col5" class="data row5 col5" >0.5706</td>
#       <td id="T_0fdf8_row5_col6" class="data row5 col6" >0.4297</td>
#       <td id="T_0fdf8_row5_col7" class="data row5 col7" >0.4325</td>
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]

# %%
print(best_model_data)
save_model(best_model_data, 'best_churn_model')
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1.0,
#                    n_estimators=50, random_state=1379)
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['tenure', 'MonthlyCharges',
#                                               'TotalCharges'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                missing_values=nan,
#                                                                strateg...
#                                      include=['Contract', 'PaymentMethod'],
#                                      transformer=OneHotEncoder(cols=['Contract',
#                                                                      'PaymentMethod'],
#                                                                drop_invariant=False,
#                                                                handle_missing='return_nan',
#                                                                handle_unknown='value',
#                                                                return_df=True,
#                                                                use_cat_names=True,
#                                                                verbose=0))),
#                  ('trained_model',
#                   AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#                                      learning_rate=1.0, n_estimators=50,
#                                      random_state=1379))],
#           verbose=False),
#  'best_churn_model.pkl')

# %%
import pandas as pd
from pycaret.classification import load_model, predict_model

# %%
def predict_churn_probabilities(input_df):
    model = load_model('best_churn_model') # loading the model data

    predictions = predict_model(model, data=input_df) # making predections

    return predictions #return model probabilities

# %%
new_data = pd.read_csv('new_churn_data.csv')
print(new_data)
new_data = new_data.drop(['customerID'], axis=1)
churn_probabilities = predict_churn_probabilities(new_data)
print(churn_probabilities)
# Out:
#    customerID  tenure  PhoneService  Contract  PaymentMethod  MonthlyCharges  \
# 0  9305-CKSKC      22             1         0              2           97.40
# 1  1452-KNGVK       8             0         1              1           77.30
# 2  6723-OKKJM      28             1         0              0           28.25
# 3  7832-POPKP      62             1         0              2          101.70
# 4  6348-TACGU      10             0         0              1           51.15
#
#    TotalCharges  charge_per_tenure
# 0        811.70          36.895455
# 1       1701.95         212.743750
# 2        250.90           8.960714
# 3       3106.56          50.105806
# 4       3440.97         344.097000
# Transformation Pipeline and Model Successfully Loaded
#    tenure  PhoneService  Contract  PaymentMethod  MonthlyCharges  \
# 0      22             1         0              2       97.400002
# 1       8             0         1              1       77.300003
# 2      28             1         0              0       28.250000
# 3      62             1         0              2      101.699997
# 4      10             0         0              1       51.150002
#
#    TotalCharges  charge_per_tenure prediction_label  prediction_score
# 0    811.700012          36.895454               No            0.5108
# 1   1701.949951         212.743744               No            0.5138
# 2    250.899994           8.960714               No            0.5200
# 3   3106.560059          50.105808               No            0.5128
# 4   3440.969971         344.096985               No            0.5210

# %% [markdown]
# # Summary

# %% [markdown]
# Write a short summary of the process and results here.
#
# I feel I was a success in achieving our objectives. PyCaret is a valuable tool in automating the model selection process, saving the best model, and creating a reusable prediction module. and then able to compare the predictions made on new data to the true values and evaluate the model's performance based on various metrics that fit business requirements.
#
# Using PyCaret made our machine learning workflow much more streamlined, allowing us to experiment with different algorithms and select the best-performing one with ease. Next deploy the prediction module in a production environment, making real-time churn predictions for new customer data.
#
# Overall, this project demonstrates how to build an end-to-end workflow for churn prediction, from data preprocessing and model selection to model deployment and testing with new data. With the help of PyCaret and a well-structured Python module, we can simplify the process of building and deploying machine learning models for business applications.
